# %% [markdown]
# # Workshop 02
#
# # YOLOv8 Object Detection Using Laptop Camera
# ## SAAGAR S (212225040351)

# %% [markdown]
# ## Aim
#
# To capture an image using the laptop camera and perform object detection using YOLOv8.

# %% [markdown]
# ## Step 1: Import Required Libraries
#
# Import OpenCV, Matplotlib, YOLO, and other required libraries.

# %%
pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in c:\users\acer\appdata\roaming\python\python310\site-packages (8.4.121)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (2.13.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: pillow>=7.1.2 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (3.32.3)
# Requirement already satisfied: requests>=2.23.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (0.28.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: polars>=0.20.0 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (1.43.2)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (2.1.6)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\acer\appdata\roaming\python\python310\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pyparsing>=3 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: polars-runtime-32==1.43.2 in c:\users\acer\appdata\roaming\python\python310\site-packages (from polars>=0.20.0->ultralytics) (1.43.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\acer\appdata\roaming\python\python310\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2.8.4)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\acer\appdata\roaming\python\python310\site-packages (from torch>=1.8.0->ultralytics) (84.0.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.5 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2022.11.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import time
import matplotlib.pyplot as plt
from ultralytics import YOLO

print("Libraries loaded")
# Out:
# Libraries loaded

# %%
import cv2
import time
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %% [markdown]
# ## Step 2: Load YOLOv8 Model
#
# Load the pretrained YOLOv8 Nano model.

# %%
model = YOLO("yolov8n.pt")

# %% [markdown]
# ## Step 3: Open Laptop Camera
#
# Access the laptop camera using OpenCV.

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open camera")
else:
    print("Camera opened successfully")
# Out:
# Camera opened successfully

# %% [markdown]
# ## Step 4: Capture Image
#
# Wait for 5 seconds and capture one image from the laptop camera.

# %%
import time

print("Camera is active...")
time.sleep(5)

ret, captured_image = cap.read()

if ret:
    print("Image captured successfully")
else:
    print("Failed to capture image")
# Out:
# Camera is active...
# Image captured successfully

# %% [markdown]
# ## Step 5: Perform Object Detection
#
# Apply YOLOv8 to the captured image.

# %%
results = model(captured_image)

print("Object detection completed")
# Out:
# 0: 480x640 4 persons, 1 chair, 1 cell phone, 122.4ms
# Speed: 5.1ms preprocess, 122.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Object detection completed

# %% [markdown]
# ## Step 6: Display Detected Image
#
# Display the image with bounding boxes and object labels.

# %%
detected_image = results[0].plot()

plt.figure(figsize=(10, 7))
plt.imshow(cv2.cvtColor(detected_image, cv2.COLOR_BGR2RGB))
plt.title("YOLOv8 Object Detection")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Step 7: Release Camera
#
# Release the laptop camera after capturing the image.

# %%
print("Camera released successfully")
# Out:
# Camera released successfully
